# %% [markdown]
# # Full Stack Web Development — Course Analytics & Curriculum Explorer
# Exploratory notebook analyzing topics, completion distributions, and XP progression.

# %%
total_html_modules = 52
total_css_modules = 49
total_modules = total_html_modules + total_css_modules
print(f"Total Curriculum Lessons: {total_modules}")
