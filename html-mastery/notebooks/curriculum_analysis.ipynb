# %% [markdown]
# # HTML & CSS Mastery — Curriculum & Progress Analytics
# Analysis of 52 HTML modules, 49 CSS lessons, and XP reward distributions.

# %%
html_topics = 52
css_topics = 49
base_xp_per_lesson = 25
quiz_xp = 100
total_potential_xp = (html_topics + css_topics) * base_xp_per_lesson + (6 * quiz_xp)
print(f"Total Curriculum Lessons: {html_topics + css_topics}")
print(f"Max Base XP Available: {total_potential_xp} XP")
